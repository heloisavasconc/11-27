# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fft, rfft
from numpy import genfromtxt

# %% [markdown]
# Carregue os sinais: EEG_2.csv, EEG_3.csv, EEG_4.csv, EEG_5.csv. Para cada sinal responda as perguntas abaixo:
#
# 1. Qual a frequência de amostragem? Qual a duração total do sinal ? Qual a resolução da frequência ? Qual a frequência de Nyquist ?
#
#
# 2. Faça o gráfico do sinal e o descreva. Algum ritmo é visível? Quais?
#
#
# 3. Calcule a autocovariância do sinal. Escolha o número de lags. Qual estrutura você observa na autocovariância?
#
#
# 4. Faça o gráfico do espectro. Você pode escolher plotar na escala decibel ou não. Justifique sua escolha.
#
#
# 5. Faça o espectrograma. Escolha os parâmetros de tamanho da janela e overlap. Os ritmos desse sinal mudam com o tempo?
#
#
# 6. Interprete a autocovariância e o espectro e descreva os ritmos nos sinais. Compare sua análise visual com a autocovariância e com o espectro. As conclusões das análises são iguais?

# %%
#SINAL 1

import csv
import numpy as np 
import matplotlib.pyplot as plt 

data= np.genfromtxt('EEG_2.csv', delimiter=',', skip_header=0)
